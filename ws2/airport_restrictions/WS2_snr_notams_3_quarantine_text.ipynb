# %% [markdown]
# # Extraction of quarantine information from NOTAMs
#
#
# In this notebook, we use the preprocessed NOTAMs dataset to search for the terms "quarantine" and "isolate" in the messages and add those messages to a separate column in the dataframe. We also run Named Entity Recognition on the filtered text to identify DATE tags. The intention in identifying DATE tags is based on the assumption that the DATE tag would correspond to quarantine duration.
#
#
# **Input**
#
# To generate the input dataset, refer this notebook: ws2_snr_NOTAMs_1_data_preparation
#
# Preprocessed datasets
#
#     - valid_airport_notams_xx.csv
#     - valid_airspace_notams_xx.csv
#
# **Output**
#
#     - valid_airport_notams_with_quarantine_xx.csv
#     - valid_airspace_notams_with_quarantine_xx.csv
#
# Datasets with additional columns corresponding to quarantine related text
#
#
# The following steps are carried out:
#
# 1. Read the preprocessed datset
#
# 2. Extract quarantine related text
#
# 3. Save the file

# %%
import requests


import spacy

from collections import Counter, defaultdict

import pandas as pd
import os
import csv
import itertools
import re
import json
import numpy as np
import matplotlib.pyplot as plt
import datetime
import ast

from spacy_langdetect import LanguageDetector
import plac
from spacy.lang.en import English
from spacy.matcher import PhraseMatcher
from spacy.tokens import Doc, Span, Token

from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import regexp_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.stem import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.naive_bayes import MultinomialNB

from wordcloud import WordCloud
from spacy import displacy
import seaborn as sbs
import geonamescache


plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# **1. Read the preprocessed datset**

# %%
apt_df = pd.read_csv("/project_data/data_asset/ws2/notams/valid_airport_notams_20200717.csv")
asp_df = pd.read_csv("/project_data/data_asset/ws2/notams/valid_airspace_notams_20200717.csv")

# %% [markdown]
# **2. Extract quarantine related text**
#
# - Load spacy
#
# - Filter for text containing the terms "quarantine" and "isolation"
#
# - Extract DATE (DAY or WEEK) tags for the filtered text

# %%
############
#Stop words#
############

nlp_ = spacy.load('en_core_web_md')

# Adding stop words
new_stop_words = ["create","source","euecyiyn",'etczyoyx','tel']

# Add airport codes to stop words
new_stop_words.extend([ac.lower() for ac in list(apt_df.airportCode.values)])

for new_word in new_stop_words:
    nlp_.vocab[new_word].is_stop = True

# %%
def extract_quarantine_info(df):
    quarantine_duration_df = df.copy()
    quarantine_duration_df['quarantine_text'] = ""
    quarantine_duration_df['quarantine_days'] = ""
    for idx, row in quarantine_duration_df.iterrows():
        quarantine_days = []
        quarantine_text = []
        message = row['cleaned_message']
        doc_ = nlp_(message)
        if ('quarantine' in row['tokens']) | ('isolation' in row['tokens']):
            for ent in doc_.ents:
                if (ent.label_ == "DATE") & (("DAY" in ent.text.upper())|("WEEK" in ent.text.upper())):
                    quarantine_days.append(ent.text)
                    quarantine_text.append(message)
                    #spacy.displacy.render(doc_, jupyter=True, style='ent',options={'ents':['DATE']})
        if not len(quarantine_days) == 0:
            quarantine_duration_df.loc[idx,'quarantine_days'] = ",".join(quarantine_days)
        if not len(quarantine_text) == 0:
            quarantine_duration_df.loc[idx,'quarantine_text'] = " ".join(quarantine_text)

    return quarantine_duration_df

# %%
apt_df = extract_quarantine_info(apt_df)
asp_df = extract_quarantine_info(asp_df)

# %% [markdown]
# **3. Save the file**

# %%
apt_df.to_csv("/project_data/data_asset/ws2/notams/valid_airport_notams_with_quarantine_20200717.csv",index=False,quoting=csv.QUOTE_NONNUMERIC)
asp_df.to_csv("/project_data/data_asset/ws2/notams/valid_airspace_notams_with_quarantine_20200717.csv",index=False,quoting=csv.QUOTE_NONNUMERIC)

# %% [markdown]
# **4. Observations**

# %%
apt_df[apt_df.quarantine_days != '']
# Out:
#                                                message Qcode  \
# 40   CONT:3.ACFT REQ RON MUST OBTAIN DGCA AIR TRANS...  XXXX
# 41   1. PER FCG & IAW GOVT OF KW COUNTER-COVID-19 P...  XXXX
# 54   COVID-19: ORDERS OF THE STATE GOVERNMENT OF BE...  FAXX
# 88   FOLLOWING THE DECLARATION OF WHO, MINISTRY OF ...  OEXX
# 290  AMEND APP/TWR HR SER: 2200 MON TO 0330 TUE 220...  STAH
# 293  - FLIGHTS TO VIETNAM: NOT ALLOWED TO CARRY PAS...  AFXX
# 321  DUE TO THE COVID-19 OUTBREAK, THE GOVERNMENT O...  XXXX
# 345  BAILIWICK OF GUERNSEY COVID-19 PROCEDURES: EXE...  FAXX
# 379  COVID-19: ORDERS OF THE STATE GOVERNMENT OF BR...  FAXX
#
#                    createdDate  Closed        airportName airportCode  \
# 40   2020-06-20 06:22:00+00:00   False        Kuwait Intl        OKBK
# 41   2020-06-20 06:20:00+00:00   False        Kuwait Intl        OKBK
# 54   2020-06-29 08:22:00+00:00   False              Tegel        EDDT
# 88                         NaN   False        Kigali Intl        HRYR
# 290  2020-06-19 18:30:00+00:00   False     Rarotonga Intl        NCRG
# 293  2020-06-16 04:26:00+00:00   False  Tan Son Nhat Intl        VVTS
# 321  2020-06-29 14:06:00+00:00   False      Bradshaw Intl        TKPK
# 345  2020-06-30 09:04:00+00:00   False           Guernsey        EGJB
# 379  2020-06-15 15:58:00+00:00   False         Schonefeld        EDDB
#
#         cityName countryCode         countryName   latitude   longitude  \
# 40        Kuwait         KWT              Kuwait  29.226767   47.979953
# 41        Kuwait         KWT              Kuwait  29.226767   47.979953
# 54        Berlin         DEU             Germany  52.559686   13.287711
# 88        Kigali         RWA              Rwanda  -1.968447   30.138386
# 290  Rarotonga I         COK             Cook Is -21.200875 -159.794950
# 293  Ho Chi Minh         VNM             Vietnam  10.820556  106.660833
# 321  St Kitts I.         KNA  St Kitts And Nevis  17.311181  -62.718686
# 345     Guernsey         GBR                  UK  49.434931   -2.602800
# 379       Berlin         DEU             Germany  52.362247   13.500672
#
#                                                 tokens  \
# 40   ['cont', 'aircraft', 'request', 'ron', 'obtain...
# 41   ['fcg', 'iaw', 'govt', 'counter', 'covid', 'pa...
# 54   ['covid', 'order', 'state', 'government', 'ber...
# 88   ['follow', 'declaration', 'ministry', 'health'...
# 290  ['amend', 'app', 'aerodrome', 'control', 'towe...
# 293  ['flight', 'vietnam', 'allow', 'carry', 'passe...
# 321  ['covid', 'outbreak', 'government', 'kitts', '...
# 345  ['bailiwick', 'guernsey', 'covid', 'procedure'...
# 379  ['covid', 'order', 'state', 'government', 'bra...
#
#                                        cleaned_message  \
# 40   cont 3 aircraft request ron must obtain dgca a...
# 41   1 per fcg iaw govt of kw counter covid 19 pand...
# 54   covid 19 orders of the state government of ber...
# 88   following the declaration of who ministry of h...
# 290  amend app aerodrome control tower hour service...
# 293  flights to vietnam not allowed to carry passen...
# 321  due to the covid 19 outbreak the government of...
# 345  bailiwick of guernsey covid 19 procedures exer...
# 379  covid 19 orders of the state government of bra...
#
#                                        quarantine_text  \
# 40   cont 3 aircraft request ron must obtain dgca a...
# 41   1 per fcg iaw govt of kw counter covid 19 pand...
# 54   covid 19 orders of the state government of ber...
# 88   following the declaration of who ministry of h...
# 290  amend app aerodrome control tower hour service...
# 293  flights to vietnam not allowed to carry passen...
# 321  due to the covid 19 outbreak the government of...
# 345  bailiwick of guernsey covid 19 procedures exer...
# 379  covid 19 orders of the state government of bra...
#
#                                        quarantine_days
# 40                                              14 day
# 41                                   14 day quarantine
# 54                                             14 days
# 88                                      7 days,the day
# 290  2200 monday,tuesday,thursday,friday 2200 frida...
# 293                                            14 days
# 321                 fourteen 14 day quarantine,14 days
# 345                            14 days,14 days,14 days
# 379                                            14 days

# %% [markdown]
# Airport NOTAMS
#
# * NOTE: for some rows the quarantine_days column might not correspond to the quarantine duration but to some other date tags in the text!
#
# * From the above dataframe, we see that for most cases the quarantine duration corresponds to 14 days. The text has to be read to get the exact quarantine regulations
#
# * Further work to be done on identifying different quarantine restrictions!

# %%
asp_df[asp_df.quarantine_days != '']
# Out:
#                                                message Qcode  \
# 16   - FLIGHTS TO VIETNAM: NOT ALLOWED TO CARRY PAS...  AFXX
# 59   COVID-19. PASSENGER RESTRICTIONS: ALL FLIGHT A...  OEXX
# 63   COVID19, TRAVEL RESTRICTIONS: NORWAY HAS START...  XXXX
# 87   COVID-19. PASSENGER RESTRICTIONS: ALL FLIGHT A...  OEXX
# 124  COVID-19: CREWS/PASSENGERS REQUIREMENTS THE RE...  AFXX
# 167  COVID-19: ALL PERSONS ENTERING THE TERRITORY O...  AFXX
# 171  IN ORDER TO PREVENT FURTHER OUTBREAK OF COVID-...  AFXX
# 189  - FLIGHTS TO VIETNAM: NOT ALLOWED TO CARRY PAS...  AFXX
# 190  FOLLOWING THE DECLARATION OF WHO, MINISTRY OF ...  OEXX
# 211  COVID-19: AUSTRALIA - TRAVEL RESTRICTIONS AND ...  PCCA
# 224  COVID-19 : PASSENGER RESTRICTIONS ALL FOREIGN ...  AFXX
# 230  COVID-19: ALL INTL, REGIONAL FLT PROHIBITED, I...  XXXX
# 250  COVID-19: PASSENGER RESTRICTIONS. ARRIVAL ENTR...  AFXX
# 258  COVID-19: AUSTRALIA - TRAVEL RESTRICTIONS AND ...  PCCA
# 262  COVID-19: RESTRICTIONS AS PRESCRIBED BY SWISS ...  OECH
# 287  - COVID-19 PASSENGER RESTRICTIONS:  BY ORDER O...  OEXX
# 298  COVID-19: PASSENGER RESTRICTIONS  BASED ON THE...  AFXX
# 307  COVID19, TRAVEL RESTRICTIONS: NORWAY HAS START...  XXXX
# 313  COVID-19. PASSENGER RESTRICTIONS: ALL FLIGHT A...  OEXX
#
#                    createdDate  Closed FIRcode               FIRname  \
# 16   2020-06-16 04:26:00+00:00   False    VVVV                 HANOI
# 59   2020-07-15 10:44:00+00:00   False    LIMM                MILANO
# 63   2020-07-10 12:50:00+00:00   False    ENOB          BODO OCEANIC
# 87   2020-07-15 10:44:00+00:00   False    LIRR                  ROMA
# 124  2020-07-13 22:27:00+00:00   False    LOVV                  WIEN
# 167  2020-07-15 20:34:00+00:00   False    LBSR                 SOFIA
# 171  2020-07-12 09:23:00+00:00   False    OIIX                TEHRAN
# 189  2020-06-16 04:26:00+00:00   False    VVTS           HO-CHI-MINH
# 190                        NaN   False    HRYR                KIGALI
# 211  2020-07-05 21:53:00+00:00   False    YBBB              BRISBANE
# 224  2020-04-19 13:05:00+00:00   False    LYBA               BEOGRAD
# 230  2020-06-30 19:50:00+00:00   False    FAJO  JOHANNESBURG OCEANIC
# 250  2020-07-14 18:07:00+00:00   False    LHCC              BUDAPEST
# 258  2020-07-05 21:53:00+00:00   False    YMMM             MELBOURNE
# 262  2020-07-06 07:09:00+00:00   False    LSAS           SWITZERLAND
# 287  2020-07-15 20:38:00+00:00   False    LGGG               ATHINAI
# 298  2020-07-14 22:07:00+00:00   False    LJLA             LJUBLJANA
# 307  2020-07-10 12:50:00+00:00   False    ENOR                NORWAY
# 313  2020-07-15 10:44:00+00:00   False    LIBB              BRINDISI
#
#     countryCode                 countryName  \
# 16          VNM                    Viet Nam
# 59          ITA                       Italy
# 63          NOR                      Norway
# 87          ITA                       Italy
# 124         AUT                     Austria
# 167         BGR                    Bulgaria
# 171         IRN  Iran (Islamic Republic of)
# 189         VNM                    Viet Nam
# 190         RWA                      Rwanda
# 211         AUS                   Australia
# 224         MNE                  Montenegro
# 230         ZAF                South Africa
# 250         HUN                     Hungary
# 258         AUS                   Australia
# 262         CHE                 Switzerland
# 287         GRC                      Greece
# 298         SVN                    Slovenia
# 307         NOR                      Norway
# 313         ITA                       Italy
#
#                                                 tokens  \
# 16   ['flight', 'vietnam', 'allow', 'carry', 'passe...
# 59   ['covid', 'passenger', 'restriction', 'flight'...
# 63   ['travel', 'restriction', 'norway', 'start', '...
# 87   ['covid', 'passenger', 'restriction', 'flight'...
# 124  ['covid', 'crew', 'passenger', 'requirement', ...
# 167  ['covid', 'person', 'enter', 'territory', 'rep...
# 171  ['order', 'prevent', 'outbreak', 'covid', 'inf...
# 189  ['flight', 'vietnam', 'allow', 'carry', 'passe...
# 190  ['follow', 'declaration', 'ministry', 'health'...
# 211  ['covid', 'australia', 'travel', 'restriction'...
# 224  ['covid', 'passenger', 'restriction', 'foreign...
# 230  ['covid', 'international', 'regional', 'flight...
# 250  ['covid', 'passenger', 'restriction', 'arrival...
# 258  ['covid', 'australia', 'travel', 'restriction'...
# 262  ['covid', 'restriction', 'prescribe', 'swiss',...
# 287  ['covid', 'passenger', 'restriction', 'order',...
# 298  ['covid', 'passenger', 'restriction', 'base', ...
# 307  ['travel', 'restriction', 'norway', 'start', '...
# 313  ['covid', 'passenger', 'restriction', 'flight'...
#
#                                        cleaned_message  \
# 16   flights to vietnam not allowed to carry passen...
# 59   covid 19 passenger restrictions all flight arr...
# 63   covid19 travel restrictions norway has started...
# 87   covid 19 passenger restrictions all flight arr...
# 124  covid 19 crews passengers requirements the rep...
# 167  covid 19 all persons entering the territory of...
# 171  in order to prevent further outbreak of covid ...
# 189  flights to vietnam not allowed to carry passen...
# 190  following the declaration of who ministry of h...
# 211  covid 19 australia travel restrictions and pas...
# 224  covid 19 passenger restrictions all foreign na...
# 230  covid 19 all international regional flight pro...
# 250  covid 19 passenger restrictions arrival entry ...
# 258  covid 19 australia travel restrictions and pas...
# 262  covid 19 restrictions as prescribed by swiss f...
# 287  covid 19 passenger restrictions by order of th...
# 298  covid 19 passenger restrictions based on the g...
# 307  covid19 travel restrictions norway has started...
# 313  covid 19 passenger restrictions all flight arr...
#
#                                        quarantine_text  \
# 16   flights to vietnam not allowed to carry passen...
# 59   covid 19 passenger restrictions all flight arr...
# 63   covid19 travel restrictions norway has started...
# 87   covid 19 passenger restrictions all flight arr...
# 124  covid 19 crews passengers requirements the rep...
# 167  covid 19 all persons entering the territory of...
# 171  in order to prevent further outbreak of covid ...
# 189  flights to vietnam not allowed to carry passen...
# 190  following the declaration of who ministry of h...
# 211  covid 19 australia travel restrictions and pas...
# 224  covid 19 passenger restrictions all foreign na...
# 230  covid 19 all international regional flight pro...
# 250  covid 19 passenger restrictions arrival entry ...
# 258  covid 19 australia travel restrictions and pas...
# 262  covid 19 restrictions as prescribed by swiss f...
# 287  covid 19 passenger restrictions by order of th...
# 298  covid 19 passenger restrictions based on the g...
# 307  covid19 travel restrictions norway has started...
# 313  covid 19 passenger restrictions all flight arr...
#
#                                        quarantine_days
# 16                                             14 days
# 59                                             14 days
# 63                                             10 days
# 87                                             14 days
# 124  the last 14 days,older than 4 days,14 days,old...
# 167                                            14 days
# 171                                  two week,14th day
# 189                                            14 days
# 190                                     7 days,the day
# 211                                            14 days
# 224                                            14 days
# 230                                      up to 21 days
# 250                        14 days,last 5 days,90 days
# 258                                            14 days
# 262                                    14 days,10 days
# 287                                             14 day
# 298                                             14 day
# 307                                            10 days
# 313                                            14 days

# %% [markdown]
# Airspace NOTAMS
#
#
# - Norway has a quarantine duration of 10 days
#
# - South Africa has a quarantine duration of upto 21 days
#
# - In some cases there is mention of 7 and 14 days in the message. The message has to be read to understand the exact quarantine regulation!
